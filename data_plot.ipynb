# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Parameters1 : V = h0 = 1 , hs = (1 2) , Gamma = 3 , omega = 1 , dt = log(2)/3 , Q = 2 , n =2

psi_approx_Q2_1 = [np.array([ 0.37136767-0.65848096j,  0.        +0.j        ,
        0.        +0.j        , -0.14990049-0.63719599j]), np.array([-0.66279766-0.32820627j,  0.        +0.j        ,
        0.        +0.j        , -0.27929144-0.612353j  ]), np.array([-0.81988497+0.55278352j,  0.        +0.j        ,
        0.        +0.j        , -0.0265504 -0.14667683j]), np.array([-0.06138976+0.90081983j,  0.        +0.j        ,
        0.        +0.j        ,  0.38485489+0.19142008j]), np.array([0.68928619+0.39037703j, 0.        +0.j        ,
       0.        +0.j        , 0.54365313+0.27736547j]), np.array([0.73832809-0.43605419j, 0.        +0.j        ,
       0.        +0.j        , 0.39619273+0.32826771j]), np.array([0.10731239-0.87306718j, 0.        +0.j        ,
       0.        +0.j        , 0.17954351+0.44045644j]), np.array([-0.67313341-0.57535995j,  0.        +0.j        ,
        0.        +0.j        ,  0.06103053+0.46057314j]), np.array([-0.94575512+0.24078021j,  0.        +0.j        ,
        0.        +0.j        , -0.04484588+0.2134502j ]), np.array([-0.40067658+0.83973675j,  0.        +0.j        ,
        0.        +0.j        , -0.31053585-0.1945969j ]), np.array([ 0.4772619 +0.50533117j,  0.        +0.j        ,
        0.        +0.j        , -0.60998769-0.38049507j]), np.array([ 0.68453692-0.51986312j,  0.        +0.j        ,
        0.        +0.j        , -0.47881901-0.17856065j]), np.array([-0.04301151-0.97950926j,  0.        +0.j        ,
        0.        +0.j        ,  0.19404907+0.03250519j]), np.array([-0.65052473-0.20338867j,  0.        +0.j        ,
        0.        +0.j        ,  0.72811552-0.07279022j]), np.array([-0.22738126+0.80149191j,  0.        +0.j        ,
        0.        +0.j        ,  0.52430659-0.17609961j]), np.array([ 0.63046747+0.7681147j,  0.        +0.j       ,
        0.        +0.j       , -0.07420874+0.0836877j]), np.array([ 0.78546408-0.12572463j,  0.        +0.j        ,
        0.        +0.j        , -0.40967203+0.44655159j]), np.array([ 0.0849086 -0.77655091j,  0.        +0.j        ,
        0.        +0.j        , -0.39258252+0.48542577j]), np.array([-0.7182655 -0.58053573j,  0.        +0.j        ,
        0.        +0.j        , -0.32121861+0.20950309j]), np.array([-0.92545775+0.18750075j,  0.        +0.j        ,
        0.        +0.j        , -0.32027581-0.07612377j])]

psi_exact_1 = [[0.410831 - 0.700851j, 0. , 0. , -0.13165 - 0.568061j] ,
             [-0.611099 - 0.446429j, 0. , 0. , -0.270912 - 0.594865j] , 
             [-0.865737 + 0.443932j, 0. , 0., -0.0909524 - 0.212487j] ,
             [-0.183677 + 0.935325j, 0. , 0. , 0.280347 + 0.113287j] , 
             [0.63096 + 0.562148j, 0. , 0. , 0.486032 + 0.222823j] , 
             [0.823604 - 0.268856j, 0. , 0. , 0.413975 + 0.279316j] , 
             [0.280689 - 0.8421j, 0. , 0. , 0.238862 + 0.393734j] , 
             [-0.541337 - 0.698771j, 0. , 0. , 0.12913 + 0.449442j] , 
             [-0.959495 + 0.0720617j, 0., 0., 0.0342523 + 0.270191j] , 
             [-0.551461 + 0.802055j, 0. , 0., -0.210155 - 0.0918265j],
             [0.345705 + 0.698538j, 0. , 0. , -0.54099 - 0.316005j] ,
             [0.760281 - 0.250455j, 0., 0. , -0.564344 - 0.201893j] , 
             [0.183581 - 0.981248j, 0. , 0. , -0.0586655 - 0.00230767j] ,
             [-0.61807 - 0.563025j, 0. , 0. , 0.545866 - 0.0549635j] , 
             [-0.548939 + 0.498566j, 0., 0., 0.635698 - 0.214442j] , 
             [0.309645 + 0.918486j, 0. , 0. , 0.22398 - 0.101663j] , 
             [0.899178 + 0.304866j, 0., 0. , -0.180814 + 0.256592j] , 
             [0.591217 - 0.563383j, 0. , 0. , -0.308169 + 0.487946j] , 
             [-0.252741 - 0.821614j, 0. , 0. , -0.305568 + 0.409511j] , 
             [-0.86684 - 0.30603j, 0. , 0. , -0.348714 + 0.182571j]]

# Parameters2 : V = 3 ,  h0 = 1 , hs = (1 2) , Gamma = 3 , omega = 4 , dt = log(2)/3 , Q = 2 , n =2

psi_approx_Q2 = [np.array([ 0.06805358-0.80043769j,  0.        +0.j        ,
        0.        +0.j        , -0.38052717-0.45811275j]), np.array([-0.78219656-0.13718641j,  0.        +0.j        ,
        0.        +0.j        , -0.46031636-0.39680887j]), np.array([-0.20854818+0.39524245j,  0.        +0.j        ,
        0.        +0.j        , -0.57121748-0.68847778j]), np.array([ 0.39767382-0.4011252j ,  0.        +0.j        ,
        0.        +0.j        , -0.6468552 -0.51237921j]), np.array([-0.31906051-0.72122513j,  0.        +0.j        ,
        0.        +0.j        , -0.38746903-0.4773913j ]), np.array([-0.77101619+0.33452152j,  0.        +0.j        ,
        0.        +0.j        , -0.4571463 -0.29094097j]), np.array([0.2624762 +0.9525553j , 0.        +0.j        ,
       0.        +0.j        , 0.15214353-0.02443326j]), np.array([0.76155411-0.18699996j, 0.        +0.j        ,
       0.        +0.j        , 0.43235113-0.44512791j]), np.array([-0.04143042-0.78298689j,  0.        +0.j        ,
        0.        +0.j        ,  0.43196633-0.44566819j]), np.array([-0.32811755-0.01141481j,  0.        +0.j        ,
        0.        +0.j        ,  0.70102893-0.63306162j]), np.array([0.56759134+0.33802144j, 0.        +0.j        ,
       0.        +0.j        , 0.46884133-0.5863185j ]), np.array([0.60257703-0.48890919j, 0.        +0.j        ,
       0.        +0.j        , 0.48620564-0.40183679j]), np.array([-0.58729354-0.66806157j,  0.        +0.j        ,
        0.        +0.j        ,  0.18900686-0.41600054j]), np.array([-0.81699262+0.4949769j ,  0.        +0.j        ,
        0.        +0.j        ,  0.09197128+0.28118004j]), np.array([0.41117232+0.6654996j, 0.        +0.j       ,
       0.        +0.j       , 0.48056879+0.39636j  ]), np.array([0.72350718-0.20046875j, 0.        +0.j        ,
       0.        +0.j        , 0.44402121+0.48907545j]), np.array([-0.1665492 -0.20212725j,  0.        +0.j        ,
        0.        +0.j        ,  0.68308897+0.68175905j]), np.array([-0.22562693+0.69107886j,  0.        +0.j        ,
        0.        +0.j        ,  0.52134543+0.44687967j]), np.array([0.63203236+0.43050801j, 0.        +0.j        ,
       0.        +0.j        , 0.43300123+0.47718748j]), np.array([0.49519689-0.79854124j, 0.        +0.j        ,
       0.        +0.j        , 0.3291286 +0.09373525j])]


psi_exact = [[0.0863833 - 0.849466j, 0., 0., -0.309276 - 0.41868j] ,
             [-0.791885 - 0.173442j, 0. , 0. , -0.419077 - 0.408913j] , 
             [-0.211185 + 0.461967j, 0. , 0. , -0.552409 - 0.660931j] ,
             [0.448508 - 0.280919j, 0. , 0., -0.673441 - 0.516142j] , 
             [-0.254194 - 0.72916j, 0. , 0. , -0.47513 - 0.421856j] , 
             [-0.786914 + 0.259194j, 0. , 0. , -0.504661 - 0.242696j] , 
             [0.224211 + 0.974465j, 0. , 0. , -0.0020646 - 0.011978j] , 
             [0.874081 - 0.0878833j, 0. , 0. , 0.315273 - 0.358972j] , 
             [0.0765897 - 0.840128j, 0. , 0. , 0.356276 - 0.401729j] , 
             [-0.475776 - 0.126492j, 0., 0. , 0.643589 - 0.586029j],
             [0.339536 + 0.436855j, 0. , 0., 0.475523 - 0.683923j] ,
             [0.654278 - 0.319831j, 0. , 0. , 0.408157 - 0.550487j] , 
             [-0.420798 - 0.686549j, 0. , 0. , 0.169011 - 0.568344j] ,
             [-0.901228 + 0.430787j, 0., 0. , 0.0449131 - 0.013862j] , 
             [0.256494 + 0.863568j, 0. , 0., 0.384284 + 0.201958j] , 
             [0.869692 - 0.0376276j, 0, 0., 0.373881 + 0.320053j] , 
             [.024625 - 0.485745j, 0. , 0. , 0.618418 + 0.617255j] , 
             [-0.426096 + 0.390843j, 0. , 0. , 0.693628 + 0.42961j] , 
             [0.370329 + 0.568684j, 0. , 0., 0.629626 + 0.378189j] , 
             [0.553095 - 0.560378j, 0., 0. , 0.608559 + 0.0985716j]]


psi_Q2_overlap_00 = [np.abs(psi_approx_Q2[i][0])**2 for i in range(len(psi_approx_Q2))]
psi_exact_overlap_00 = [np.abs(psi_exact[i][0])**2 for i in range(len(psi_exact))]
psi_Q2_overlap_11 = [np.abs(psi_approx_Q2[i][3])**2 for i in range(len(psi_approx_Q2))]
psi_exact_overlap_11 = [np.abs(psi_exact[i][3])**2 for i in range(len(psi_exact))]
dt = np.log(2)/3.0
time = dt*np.arange(1, len(psi_exact)+1)

# %%
plt.figure(figsize=(10, 6))
plt.plot(time, psi_Q2_overlap_00, label='Q=2 overlap w |00>', color='blue' , marker='x')
plt.plot(time, psi_exact_overlap_00, label='Exact overlap w |00>', color='green' , marker='o')
plt.title('The approximate and exact overlap with the |00> state')
plt.xlabel('Time')
plt.ylabel('Overlap amplitude')
plt.legend()
plt.savefig('Q=2_n=2_V=3_h=1_Gam=3_Omega=4_start|00>_overlap|00>.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(time, psi_Q2_overlap_11, label='Q=2 overlap w |11>', color='blue' , marker='x')
plt.plot(time, psi_exact_overlap_11, label='Exact overlap w |11>', color='green' , marker='o')
plt.title('The approximate and exact overlap with the |11> state')
plt.xlabel('Time')
plt.ylabel('Overlap amplitude')
plt.legend()
plt.savefig('Q=2_n=2_n=2_V=3_h=1_Gam=3_Omega=4_start|00>_overlap|11>.png')
plt.show()
